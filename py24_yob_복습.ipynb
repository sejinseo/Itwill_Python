# %% [markdown]
# <a href="https://colab.research.google.com/github/sejinseo/Python/blob/main/py24_yob_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #미국 신생아 이름 데이터 셋
# * https://github.com/wesm/pydata-book/tree/2nd-edition/datasets/babynames
# * 1880 ~ 2010 연도별로 파일이 나눠져 있음.
# * 각 파일에는 '이름,성별,신생아수'가 comma로 구분되어 있음.

# %%
file_1880 = 'https://github.com/wesm/pydata-book/raw/2nd-edition/datasets/babynames/yob1880.txt'
df = pd.read_csv(file_1880)

# %%
df.head()
# Out:
#         Mary  F  7065
# 0       Anna  F  2604
# 1       Emma  F  2003
# 2  Elizabeth  F  1939
# 3     Minnie  F  1746
# 4   Margaret  F  1578

# %%
col_names = ['name', 'gender', 'births']
df = pd.read_csv(file_1880, names=col_names)

# %%
df.head()
# Out:
#         name gender  births
# 0       Mary      F    7065
# 1       Anna      F    2604
# 2       Emma      F    2003
# 3  Elizabeth      F    1939
# 4     Minnie      F    1746

# %%
df.tail()
# Out:
#            name gender  births
# 1995     Woodie      M       5
# 1996     Worthy      M       5
# 1997     Wright      M       5
# 1998       York      M       5
# 1999  Zachariah      M       5

# %%
yobs = [] # 각 연도의 데이터 프레임을 append할 빈 리스트
for year in range(1880, 2011):
    # txt 파일이 저장된 파일 경로
    file_path = f'https://github.com/wesm/pydata-book/raw/2nd-edition/datasets/babynames/yob{year}.txt'
    df = pd.read_csv(file_path, names=col_names)
    # 생성된 DataFrame에 'year' 컬럼을 추가
    df['year'] = year
    # 해당 연도의 DataFrame을 리스트에 추가
    yobs.append(df)

# %%
# yobs 리스트의 아이템의 개수
len(yobs) #> 131개의 DataFrame을 저장하고 있는 리스트
# Out:
# 131

# %%
yobs[0] #> 리스트의 첫번째 원소: 1880년 DataFrame
# Out:
#            name gender  births  year
# 0          Mary      F    7065  1880
# 1          Anna      F    2604  1880
# 2          Emma      F    2003  1880
# 3     Elizabeth      F    1939  1880
# 4        Minnie      F    1746  1880
# ...         ...    ...     ...   ...
# 1995     Woodie      M       5  1880
# 1996     Worthy      M       5  1880
# 1997     Wright      M       5  1880
# 1998       York      M       5  1880
# 1999  Zachariah      M       5  1880
#
# [2000 rows x 4 columns]

# %%
yobs[-1] #> 리스트의 마지막 원소: 2010년 DataFrame
# Out:
#             name gender  births  year
# 0       Isabella      F   22731  2010
# 1         Sophia      F   20477  2010
# 2           Emma      F   17179  2010
# 3         Olivia      F   16860  2010
# 4            Ava      F   15300  2010
# ...          ...    ...     ...   ...
# 33833    Zymaire      M       5  2010
# 33834     Zyonne      M       5  2010
# 33835  Zyquarius      M       5  2010
# 33836      Zyran      M       5  2010
# 33837      Zzyzx      M       5  2010
#
# [33838 rows x 4 columns]

# %%
# 131개의 DataFrame을 길게 이어붙임(concatenate)
df = pd.concat(yobs, ignore_index=True) # ignore_index: 합쳐주는 DF들의 인덱스를 유지하지 않음.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690784 entries, 0 to 1690783
# Data columns (total 4 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   name    1690784 non-null  object
#  1   gender  1690784 non-null  object
#  2   births  1690784 non-null  int64
#  3   year    1690784 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 51.6+ MB

# %%
df.head()
# Out:
#         name gender  births  year
# 0       Mary      F    7065  1880
# 1       Anna      F    2604  1880
# 2       Emma      F    2003  1880
# 3  Elizabeth      F    1939  1880
# 4     Minnie      F    1746  1880

# %%
df.tail()
# Out:
#               name gender  births  year
# 1690779    Zymaire      M       5  2010
# 1690780     Zyonne      M       5  2010
# 1690781  Zyquarius      M       5  2010
# 1690782      Zyran      M       5  2010
# 1690783      Zzyzx      M       5  2010

# %%
# 연도별 신생아 숫자
births_by_year = df.groupby(by='year')['births'].sum()
births_by_year
# Out:
# year
# 1880     201486
# 1881     192703
# 1882     221538
# 1883     216954
# 1884     243466
#          ...
# 2006    3946702
# 2007    3986130
# 2008    3915955
# 2009    3801002
# 2010    3657392
# Name: births, Length: 131, dtype: int64

# %%
plt.plot(births_by_year.index, births_by_year.values)
plt.xlabel('year')
plt.grid()
plt.ylabel('# of births')
plt.show()

# %%
sns.lineplot(x='year', y='births', data=df, estimator=np.sum, err_style=None)
plt.show()

# %%
sns.lineplot(x=births_by_year.index, y=births_by_year.values)
plt.show()

# %%
# 연도별 성별 신생아 수
by_year_gender = df.groupby(by=['year', 'gender'])['births'].sum()
by_year_gender
# Out:
# year  gender
# 1880  F           90993
#       M          110493
# 1881  F           91955
#       M          100748
# 1882  F          107851
#                  ...
# 2008  M         2032310
# 2009  F         1827643
#       M         1973359
# 2010  F         1759010
#       M         1898382
# Name: births, Length: 262, dtype: int64

# %%
type(by_year_gender)
# Out:
# pandas.core.series.Series

# %%
sns.lineplot(x='year', y=by_year_gender.values, hue='gender', data=by_year_gender)
plt.show()

# %%
# Series 또는 DataFrame의 index(인덱스)를 DataFrame의 컬럼으로 변화
df_by_year_gender = by_year_gender.reset_index()
df_by_year_gender
# Out:
#      year gender   births
# 0    1880      F    90993
# 1    1880      M   110493
# 2    1881      F    91955
# 3    1881      M   100748
# 4    1882      F   107851
# ..    ...    ...      ...
# 257  2008      M  2032310
# 258  2009      F  1827643
# 259  2009      M  1973359
# 260  2010      F  1759010
# 261  2010      M  1898382
#
# [262 rows x 3 columns]

# %%
sns.lineplot(x='year', y='births', hue='gender', data=df_by_year_gender)
plt.show()
